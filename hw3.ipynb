# %%
from IPython.display import Image, display

# %% [markdown]
# ### Questão 01
#
# item b

# %%
display(Image(filename='hw3_pics/q1.jpg'))

# %% [markdown]
# ### Questão 02
#
# item c

# %%
display(Image(filename='hw3_pics/q2.jpg'))

# %% [markdown]
# ### Questão 03
#
# item d

# %%
display(Image(filename='hw3_pics/q3.jpg'))

# %% [markdown]
# ### Questão 04
#
# item b
#
# Esse foi comprovado em aulas posteriores, que prova que a dvc do perceptron é igual a d + 1, d sendo a dimensão. Logo, nesse caso o dvc = 4 e k = 5, que é o item b.

# %%
display(Image(filename='hw3_pics/q4.jpg'))

# %% [markdown]
# ### Questão 05
# item b

# %%
display(Image(filename='hw3_pics/q5.jpg'))

# %% [markdown]
# ### Questão 06
# item c

# %%
display(Image(filename='hw3_pics/q6.jpg'))

# %% [markdown]
# ### Questão 07
# item d

# %%
display(Image(filename='hw3_pics/q7.jpg'))

# %% [markdown]
# ### Questão 08
#
# item d

# %%
display(Image(filename='hw3_pics/q8.jpg'))

# %% [markdown]
# ### Questão 09
#
# item d?
#
# testei de forma semelhante a imagem, tentando encaixar as quantidades de pontos com o triangulo. Com 7 pareceu funcionar, com 8 a combinação 1375 parece impossivel fazer, então o item d seria a resposta

# %%
display(Image(filename='hw3_pics/q9_1.jpg'))
display(Image(filename='hw3_pics/q9_2.jpg'))

# %% [markdown]
# ### Questão 10
#
# fiz alguns testes com o circulo assim, mas fiquei confusa, não consegui

# %%
display(Image(filename='hw3_pics/q10.jpg'))
